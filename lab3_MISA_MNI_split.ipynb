# %% [markdown]
# <a href="https://colab.research.google.com/github/workwithjahan/MISA_Atlas-Segmentation/blob/main/lab3_MISA_MNI_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# By Eashrat Jahan Muniya, Farahdiba Zarin, Ruth Kehali Kassahun
from google.colab import drive
import nibabel as nib
from glob import glob
import os 
import glob

import numpy as np
import matplotlib.pyplot as plt
from nibabel.testing import data_path

# %%
import os
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from numpy.linalg import inv, det, norm
from math import sqrt, pi
from functools import partial
from scipy.spatial.distance import dice
import time
import operator
import math

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
MNI=nib.load('/content/drive/MyDrive/MISA_MIRA_3/MNI/atlas.nii')

# %%
plt.imshow(MNI.get_fdata()[:,100,:,2])# seeing the intensity  #3-wm

# %%
MNI_atlas_data= MNI.get_fdata()

# %%
MNI_atlas_data

# %%
MNI_csf=MNI_atlas_data[:,:,:,1]
MNI_GM=MNI_atlas_data[:,:,:,2]
MNI_WM=MNI_atlas_data[:,:,:,3]

# %% [markdown]
# save MNI atlas

# %%
img=nib.Nifti1Image(MNI_csf,MNI.affine)
img.header.get_xyzt_units()
img.to_filename(os.path.join('/content/drive/MyDrive/MISA_MIRA_3/MNI/','MNI_csf_atlasf.nii'))

# %%
img1=nib.Nifti1Image(MNI_GM,MNI.affine)
img1.header.get_xyzt_units()
img1.to_filename(os.path.join('/content/drive/MyDrive/MISA_MIRA_3/MNI/','MNI_gm_atlasf.nii'))

# %%
img3=nib.Nifti1Image(MNI_WM,MNI.affine)
img3.header.get_xyzt_units()
img3.to_filename(os.path.join('/content/drive/MyDrive/MISA_MIRA_3/MNI/','MNI_wm_atlasf.nii'))
